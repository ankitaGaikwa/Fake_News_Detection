# %%
import numpy as np
import pandas as pd
import json
import csv
import random

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers

import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()

# Reading the data
data = pd.read_csv("news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# encoding the labels
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
	title.append(data['title'][x])
	text.append(data['text'][x])
	labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
	sequences1, padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
with open('glove.6B.50d.txt') as f:
	for line in f:
		values = line.split()
		word = values[0]
		coefs = np.asarray(values[1:], dtype='float32')
		embeddings_index[word] = coefs

# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
	embedding_vector = embeddings_index.get(word)
	if embedding_vector is not None:
		embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
	tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
							input_length=max_length, weights=[
								embeddings_matrix],
							trainable=False),
	tf.keras.layers.Dropout(0.2),
	tf.keras.layers.Conv1D(64, 5, activation='relu'),
	tf.keras.layers.MaxPooling1D(pool_size=4),
	tf.keras.layers.LSTM(64),
	tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
			optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 50)            377600
#
#  dropout (Dropout)           (None, 54, 50)            0
#
#  conv1d (Conv1D)             (None, 50, 64)            16064
#
#  max_pooling1d (MaxPooling1  (None, 12, 64)            0
#  D)
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 426753 (1.63 MB)
# Trainable params: 49153 (192.00 KB)
# Non-trainable params: 377600 (1.44 MB)
# _________________________________________________________________

# %%
num_epochs = 50

training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)

history = model.fit(training_padded, training_labels,
					epochs=num_epochs,
					validation_data=(testing_padded,
									testing_labels),
					verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training_v1.py:2335: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2700/2700 - 2s - loss: 0.6572 - accuracy: 0.6000 - val_loss: 0.5573 - val_accuracy: 0.7133 - 2s/epoch - 869us/sample
# Epoch 2/50
# 2700/2700 - 2s - loss: 0.5727 - accuracy: 0.7033 - val_loss: 0.5277 - val_accuracy: 0.7300 - 2s/epoch - 663us/sample
# Epoch 3/50
# 2700/2700 - 2s - loss: 0.5509 - accuracy: 0.7289 - val_loss: 0.4950 - val_accuracy: 0.7500 - 2s/epoch - 809us/sample
# Epoch 4/50
# 2700/2700 - 2s - loss: 0.4852 - accuracy: 0.7722 - val_loss: 0.4714 - val_accuracy: 0.7533 - 2s/epoch - 885us/sample
# Epoch 5/50
# 2700/2700 - 2s - loss: 0.4460 - accuracy: 0.7863 - val_loss: 0.4674 - val_accuracy: 0.7767 - 2s/epoch - 558us/sample
# Epoch 6/50
# 2700/2700 - 2s - loss: 0.3877 - accuracy: 0.8285 - val_loss: 0.5054 - val_accuracy: 0.7400 - 2s/epoch - 558us/sample
# Epoch 7/50
# 2700/2700 - 2s - loss: 0.3486 - accuracy: 0.8396 - val_loss: 0.5244 - val_accuracy: 0.7533 - 2s/epoch - 556us/sample
# Epoch 8/50
# 2700/2700 - 2s - loss: 0.3245 - accuracy: 0.8585 - val_loss: 0.4600 - val_accuracy: 0.7700 - 2s/epoch - 573us/sample
# Epoch 9/50
# 2700/2700 - 2s - loss: 0.3060 - accuracy: 0.8704 - val_loss: 0.5216 - val_accuracy: 0.7767 - 2s/epoch - 679us/sample
# Epoch 10/50
# 2700/2700 - 2s - loss: 0.2772 - accuracy: 0.8833 - val_loss: 0.5350 - val_accuracy: 0.7833 - 2s/epoch - 561us/sample
# Epoch 11/50
# 2700/2700 - 3s - loss: 0.2449 - accuracy: 0.9067 - val_loss: 0.5904 - val_accuracy: 0.7600 - 3s/epoch - 1ms/sample
# Epoch 12/50
# 2700/2700 - 2s - loss: 0.2266 - accuracy: 0.9156 - val_loss: 0.5218 - val_accuracy: 0.8000 - 2s/epoch - 646us/sample
# Epoch 13/50
# 2700/2700 - 2s - loss: 0.2197 - accuracy: 0.9115 - val_loss: 0.5346 - val_accuracy: 0.7800 - 2s/epoch - 556us/sample
# Epoch 14/50
# 2700/2700 - 1s - loss: 0.2016 - accuracy: 0.9215 - val_loss: 0.5414 - val_accuracy: 0.7767 - 1s/epoch - 552us/sample
# Epoch 15/50
# 2700/2700 - 2s - loss: 0.1704 - accuracy: 0.9333 - val_loss: 0.5842 - val_accuracy: 0.8033 - 2s/epoch - 564us/sample
# Epoch 16/50
# 2700/2700 - 2s - loss: 0.1738 - accuracy: 0.9315 - val_loss: 0.6050 - val_accuracy: 0.7733 - 2s/epoch - 556us/sample
# Epoch 17/50
# 2700/2700 - 2s - loss: 0.1472 - accuracy: 0.9419 - val_loss: 0.7792 - val_accuracy: 0.7533 - 2s/epoch - 557us/sample
# Epoch 18/50
# 2700/2700 - 2s - loss: 0.1618 - accuracy: 0.9367 - val_loss: 0.7552 - val_accuracy: 0.7567 - 2s/epoch - 625us/sample
# Epoch 19/50
# 2700/2700 - 3s - loss: 0.1452 - accuracy: 0.9470 - val_loss: 0.6376 - val_accuracy: 0.7967 - 3s/epoch - 1ms/sample
# Epoch 20/50
# 2700/2700 - 2s - loss: 0.1346 - accuracy: 0.9459 - val_loss: 0.5873 - val_accuracy: 0.8033 - 2s/epoch - 569us/sample
# Epoch 21/50
# 2700/2700 - 2s - loss: 0.1209 - accuracy: 0.9533 - val_loss: 0.5620 - val_accuracy: 0.7867 - 2s/epoch - 569us/sample
# Epoch 22/50
# 2700/2700 - 2s - loss: 0.1251 - accuracy: 0.9511 - val_loss: 0.5855 - val_accuracy: 0.8000 - 2s/epoch - 585us/sample
# Epoch 23/50
# 2700/2700 - 2s - loss: 0.1181 - accuracy: 0.9522 - val_loss: 0.7234 - val_accuracy: 0.7900 - 2s/epoch - 585us/sample
# Epoch 24/50
# 2700/2700 - 2s - loss: 0.1154 - accuracy: 0.9570 - val_loss: 0.7459 - val_accuracy: 0.7900 - 2s/epoch - 583us/sample
# Epoch 25/50
# 2700/2700 - 2s - loss: 0.1121 - accuracy: 0.9581 - val_loss: 0.7097 - val_accuracy: 0.7633 - 2s/epoch - 583us/sample
# Epoch 26/50
# 2700/2700 - 2s - loss: 0.1066 - accuracy: 0.9604 - val_loss: 0.6460 - val_accuracy: 0.7600 - 2s/epoch - 833us/sample
# Epoch 27/50
# 2700/2700 - 2s - loss: 0.1110 - accuracy: 0.9607 - val_loss: 0.8517 - val_accuracy: 0.7367 - 2s/epoch - 874us/sample
# Epoch 28/50
# 2700/2700 - 2s - loss: 0.1219 - accuracy: 0.9570 - val_loss: 0.7939 - val_accuracy: 0.7600 - 2s/epoch - 561us/sample
# Epoch 29/50
# 2700/2700 - 1s - loss: 0.0991 - accuracy: 0.9630 - val_loss: 0.6099 - val_accuracy: 0.7800 - 1s/epoch - 548us/sample
# Epoch 30/50
# 2700/2700 - 2s - loss: 0.1009 - accuracy: 0.9644 - val_loss: 0.6984 - val_accuracy: 0.7667 - 2s/epoch - 562us/sample
# Epoch 31/50
# 2700/2700 - 1s - loss: 0.0937 - accuracy: 0.9656 - val_loss: 0.7310 - val_accuracy: 0.7667 - 1s/epoch - 554us/sample
# Epoch 32/50
# 2700/2700 - 2s - loss: 0.0853 - accuracy: 0.9670 - val_loss: 0.7234 - val_accuracy: 0.7900 - 2s/epoch - 572us/sample
# Epoch 33/50
# 2700/2700 - 1s - loss: 0.0963 - accuracy: 0.9674 - val_loss: 0.7280 - val_accuracy: 0.7733 - 1s/epoch - 555us/sample
# Epoch 34/50
# 2700/2700 - 2s - loss: 0.0796 - accuracy: 0.9719 - val_loss: 0.8229 - val_accuracy: 0.7667 - 2s/epoch - 913us/sample
# Epoch 35/50
# 2700/2700 - 2s - loss: 0.0960 - accuracy: 0.9656 - val_loss: 0.7787 - val_accuracy: 0.7733 - 2s/epoch - 780us/sample
# Epoch 36/50
# 2700/2700 - 1s - loss: 0.0750 - accuracy: 0.9770 - val_loss: 0.7165 - val_accuracy: 0.7900 - 1s/epoch - 551us/sample
# Epoch 37/50
# 2700/2700 - 2s - loss: 0.0850 - accuracy: 0.9689 - val_loss: 0.7463 - val_accuracy: 0.7767 - 2s/epoch - 560us/sample
# Epoch 38/50
# 2700/2700 - 2s - loss: 0.0921 - accuracy: 0.9670 - val_loss: 0.6914 - val_accuracy: 0.7767 - 2s/epoch - 569us/sample
# Epoch 39/50
# 2700/2700 - 2s - loss: 0.0761 - accuracy: 0.9722 - val_loss: 0.8359 - val_accuracy: 0.7567 - 2s/epoch - 570us/sample
# Epoch 40/50
# 2700/2700 - 1s - loss: 0.0804 - accuracy: 0.9722 - val_loss: 0.7572 - val_accuracy: 0.7833 - 1s/epoch - 549us/sample
# Epoch 41/50
# 2700/2700 - 2s - loss: 0.0770 - accuracy: 0.9722 - val_loss: 0.8254 - val_accuracy: 0.7700 - 2s/epoch - 564us/sample
# Epoch 42/50
# 2700/2700 - 3s - loss: 0.0690 - accuracy: 0.9759 - val_loss: 0.7934 - val_accuracy: 0.7333 - 3s/epoch - 1ms/sample
# Epoch 43/50
# 2700/2700 - 2s - loss: 0.0658 - accuracy: 0.9756 - val_loss: 0.8698 - val_accuracy: 0.7567 - 2s/epoch - 673us/sample
# Epoch 44/50
# 2700/2700 - 2s - loss: 0.0550 - accuracy: 0.9804 - val_loss: 0.9749 - val_accuracy: 0.7833 - 2s/epoch - 569us/sample
# Epoch 45/50
# 2700/2700 - 2s - loss: 0.0701 - accuracy: 0.9767 - val_loss: 0.7234 - val_accuracy: 0.7967 - 2s/epoch - 574us/sample
# Epoch 46/50
# 2700/2700 - 2s - loss: 0.0725 - accuracy: 0.9759 - val_loss: 0.7037 - val_accuracy: 0.7633 - 2s/epoch - 562us/sample
# Epoch 47/50
# 2700/2700 - 1s - loss: 0.0748 - accuracy: 0.9726 - val_loss: 1.0019 - val_accuracy: 0.7600 - 1s/epoch - 553us/sample
# Epoch 48/50
# 2700/2700 - 2s - loss: 0.0532 - accuracy: 0.9819 - val_loss: 0.8415 - val_accuracy: 0.7767 - 2s/epoch - 556us/sample
# Epoch 49/50
# 2700/2700 - 2s - loss: 0.0514 - accuracy: 0.9811 - val_loss: 0.8324 - val_accuracy: 0.7600 - 2s/epoch - 682us/sample
# Epoch 50/50
# 2700/2700 - 3s - loss: 0.0552 - accuracy: 0.9774 - val_loss: 0.9839 - val_accuracy: 0.7467 - 3s/epoch - 1ms/sample

# %%
# sample text to check if fake or not
X = "The Battle of New York: Why This Primary Matters	"

# detection
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
						padding=padding_type,
						truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
	print("This news is True")
else:
	print("This news is false")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1d5cd21cfe26> in <cell line: 5>()
#       3
#       4 # detection
# ----> 5 sequences = tokenizer1.texts_to_sequences([X])[0]
#       6 sequences = pad_sequences([sequences], maxlen=54,
#       7                                                 padding=padding_type,
#
# NameError: name 'tokenizer1' is not defined
